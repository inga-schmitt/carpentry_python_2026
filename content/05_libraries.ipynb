# %%
# ein Modul importieren und nutzen

import string

# %%
string.ascii_lowercase   # dot notation, tab completion

# %%
print(f'Die ASCII Kleinbuchstaben lauten {string.ascii_lowercase}.')
# Out:
# Die ASCII Kleinbuchstaben lauten abcdefghijklmnopqrstuvwxyz.

# %%
print(string.capwords('schreibe alle anfangsbuchstaben groß'))
# Out:
# Schreibe Alle Anfangsbuchstaben Groß

# %%
help(string)
# Out:
# Help on package string:
#
# NAME
#     string - A collection of string constants.
#
# DESCRIPTION
#     Public module variables:
#
#     whitespace -- a string containing all ASCII whitespace
#     ascii_lowercase -- a string containing all ASCII lowercase letters
#     ascii_uppercase -- a string containing all ASCII uppercase letters
#     ascii_letters -- a string containing all ASCII letters
#     digits -- a string containing all ASCII decimal digits
#     hexdigits -- a string containing all ASCII hexadecimal digits
#     octdigits -- a string containing all ASCII octal digits
#     punctuation -- a string containing all ASCII punctuation characters
#     printable -- a string containing all ASCII characters considered printable
#
# PACKAGE CONTENTS
#     templatelib
#
# CLASSES
#     builtins.object
#         Formatter
#         Template
#
#     class Formatter(builtins.object)
#      |  Methods defined here:
#      |
#      |  check_unused_args(self, used_args, args, kwargs)
# ...

# %%
# nur bestimmten Aspekt importieren

from string import ascii_letters

print(f'Die ASCII Buchstaben sind {ascii_letters}')
# Out:
# Die ASCII Buchstaben sind abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
# ein Modul installieren
# https://pymarc.readthedocs.io/en/latest/

import pymarc  # gibt es aber offenbar noch nicht
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 # ein Modul installieren
# ----> 3 import pymarc
#
# ModuleNotFoundError: No module named 'pymarc'

# %%
# pip - python package index, benötigt Internetverbindung, wird lokal bzw. in der Jupyter environment installiert

# %pip install pymarc

# %%
import pymarc

# %%
# import mit Alias

import pandas as pd    # Konvention, siehe auch Dokumentation
import numpy as np
import matplotlib as plt

# %%
# Pandas library: tabellarische Daten einlesen

import pandas as pd

# %%
df = pd.read_csv('data/2011_circ.csv')  # comma separated values, Pfad zu der Datei, die gelesen werden soll, als string

# %%
df.head()  # erste 5 Zeilen werden ausgegeben, ansonsten in die Klammer andere Zahl eingeben
# Out:
#            branch                  address     city  zip code  january  \
# 0     Albany Park     5150 N. Kimball Ave.  Chicago   60625.0     8427
# 1         Altgeld    13281 S. Corliss Ave.  Chicago   60827.0     1258
# 2  Archer Heights      5055 S. Archer Ave.  Chicago   60632.0     8104
# 3          Austin        5615 W. Race Ave.  Chicago   60644.0     1755
# 4   Austin-Irving  6100 W. Irving Park Rd.  Chicago   60634.0    12593
#
#    february  march  april    may   june   july  august  september  october  \
# 0      7023   9702   9344   8865  11650  11778   11306      10466    10997
# 1       708    854    804    816    870    713     480        702      927
# 2      6899   9329   9124   7472   8314   8116    9177       9033     9709
# 3      1316   1942   2200   2133   2359   2080    2405       2417     2571
# 4     11791  14807  14382  11754  14402  14605   15164      14306    15357
#
#    november  december     ytd
# 0     10567      9934  120059
# ...

# %%
df.info()   # Info über den dataframe: Anzahl der Spalten und Zeilen, Datentypen
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   branch     80 non-null     str
#  1   address    80 non-null     str
#  2   city       80 non-null     str
#  3   zip code   80 non-null     float64
#  4   january    80 non-null     int64
#  5   february   80 non-null     int64
#  6   march      80 non-null     int64
#  7   april      80 non-null     int64
#  8   may        80 non-null     int64
#  9   june       80 non-null     int64
#  10  july       80 non-null     int64
#  11  august     80 non-null     int64
#  12  september  80 non-null     int64
#  13  october    80 non-null     int64
#  14  november   80 non-null     int64
#  15  december   80 non-null     int64
#  16  ytd        80 non-null     int64
# dtypes: float64(1), int64(13), str(3)
# memory usage: 9.8 KB

# %%
df.columns   # Spaltennamen
# Out:
# Index(['branch', 'address', 'city', 'zip code', 'january', 'february', 'march',
#        'april', 'may', 'june', 'july', 'august', 'september', 'october',
#        'november', 'december', 'ytd'],
#       dtype='str')

# %%
# statistische Zusammenfassung der numerischen Spalten

df.describe()
# Out:
#            zip code       january      february        march         april  \
# count     80.000000     80.000000     80.000000     80.00000     80.000000
# mean   60632.675000   7216.175000   6247.162500   8367.36250   8209.225000
# std       28.001254  10334.622299   8815.945718  11667.93342  11241.223544
# min    60605.000000      0.000000      0.000000      0.00000      0.000000
# 25%    60617.000000   2388.500000   1979.250000   2708.50000   2864.250000
# 50%    60629.000000   5814.500000   5200.000000   6468.50000   6286.000000
# 75%    60643.000000   9021.000000   8000.000000  10737.00000  10794.250000
# max    60827.000000  79210.000000  67574.000000  89122.00000  88527.000000
#
#                 may          june          july        august     september  \
# count     80.000000     80.000000     80.000000     80.000000     80.000000
# mean    7551.725000   8581.125000   8708.887500   8918.550000   8289.975000
# ...

# %%
# Übung: Alias

import string as s
numbers = s.digits
print(numbers)
# Out:
# 0123456789

# %%
numbers = string.digits
print(numbers)
# Out:
# 0123456789

# %%
# Übung: passende Bibliothek finden

year = 1971
month = 8
day = 26

import datetime

iso_date = datetime.date(year, month, day).isoformat()
print(iso_date)
# Out:
# 1971-08-26
